# %% [markdown]
# # 여름방학 파이썬스터디 Competiton
#
# ※ 유의사항 ※
# #####
# 1. 시험 제한시간 : 2시간 (14:00 ~ 16:00)
# #####
# 2. 제한 시간 내에 문제를 다 푼 학생은 먼저 퇴실 가능합니다.
#    (단, 제출 후 멘토의 확인 후 퇴실 가능.
#     확인 시 문제 풀이의 정도가 퇴실 불가능 하다고 판단 될 경우 퇴실 불가)
# #####
# 3. 제한시간 내로 문제를 다 못 푸셔도 16시까지 푼데까지 구글폼으로 제출해주세요.
# #####
# 4. 제출파일 형식 : html 입니다.
# #####
# 5. 파일명 : 파이썬스터디_본인이름
# #####
# 6. 문제는 수업자료, 과제에서 기반하여 만든 문제입니다.
#    기존 수업자료, 과제 모두 참조 가능하며, 구글링도 가능합니다.
#    단!! 메신저 사용(카톡 등) 은 불가합니다.!!
# #####
#
# --  파일명과 형식을 꼭 지켜주세요.
#
# 제출 : https://forms.gle/3zo5f5ec5v29PQfz8

# %% [markdown]
# ### 1) 아래 string 이란 변수를 활용하여 문자열 '홀' 만 출력하세요.
#
# (아래 실행 예 처럼 나와야합니다 ! // 하나의 문자열로 !)
#
# 실행 예:
# 홀홀홀

# %%
string = "홀짝홀짝홀짝"

# %%
# 답안
string[0]*3
# Out:
# '홀홀홀'

# %% [markdown]
# ### 2) 아래 string2 이란 변수를 활용하여 실행 예시와 같이 출력해주세요
# 실행 예:
# 스터디여름방학파이썬

# %%
string2 = '여름방학파이썬스터디'

# %%
# 답안
string2[7:10]+string2[0:7]
# Out:
# '스터디여름방학파이썬'

# %% [markdown]
# ### 3) 아래 duplication 변수를 활용해서 리스트 속 문자열의 중복을 제거해주세요.

# %%
duplication = ['a','b','c','d','g','h','c','d','i','e','f','g','h','c','d','g','h','c','d','i','c','d','b','c','l','b','c','i','h','c','d','g','h','c','d','i','c','d','b','c','g','h','c','d','i','e','f','g','h','c','d','g','h','c','d','i','c','d','b','c','l','b']

# %%
# 답안
duplication =set(duplication);duplication
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'l'}

# %% [markdown]
# ### 4) 아래 코드를 실행하고 오류가 난 원인을 분석해서 적어주세요

# %%
t = (1, 2, 3)
t[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-30ae5ed3acb9> in <module>
#       1 t = (1, 2, 3)
# ----> 2 t[0] = 'a'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 답안

'''
답안 : 
튜플은 안에 있는 값을 변형이 안됨


'''

# %% [markdown]
# ### 5) 아래의 표를 참고하여 팝콘 이름을 키값으로, (가격, 수량) 리스트를 속성 값으로 가지는 딕셔너리를 cgv라는 이름의 변수에 저장해 출력해주세요
#
#
# | 이름 | 가격 | 수량 |
# |:--------|:--------:|--------:|
# | 고소팝콘 | 4500 | 100 |
# | 달콤팝콘 | 5500 | 57 |

# %%
# 답안
cgv = {'고소팝콘':(4500,100),'달콘팝콘':(5500,57)};cgv
# Out:
# {'고소팝콘': (4500, 100), '달콘팝콘': (5500, 57)}

# %% [markdown]
# ### 6) 위 5번 문제의 cgv라는 변수를 통해 '달콤팝콘'의 가격을 출력해주세요
#
# 실행 예시:
# 5500 원

# %%
# 답안
cgv['달콘팝콘'][0]
# Out:
# 5500

# %% [markdown]
# ### 7) 위 5번 문제의 cgv 변수에 아래와 같은 내용을 추가한 후 cgv변수를 활용해 팝콘이름으로만 구성된 리스트를 출력해주세요
#
# | 이름 | 가격 | 수량 |
# |:--------|:--------:|--------:|
# | 어니언팝콘 | 5500 | 98 |
# | 치즈팝콘 | 5500 | 67 |
#
#
# * 팝콘이름을 직접 타이핑해서 리스트를 만드는 건 금지입니다 ! cgv변수를 활용해주세요 !!
#
# 실행 예시 : ['고소팝콘', '달콤팝콘', '어니언팝콘', '치즈팝콘']

# %%
# 답안
cgv['어니언팝콘']=(5500,98)
cgv['치즈팝콘']=(5500,67)
cgv
# Out:
# {'고소팝콘': (4500, 100),
#  '달콘팝콘': (5500, 57),
#  '어니언팝콘': (5500, 98),
#  '치즈팝콘': (5500, 67)}

# %% [markdown]
# ### 8)
# #### (1) 다음의 품목으로 `icecream` 이라는딕셔너리를 만들어주세요.
# ####       아이스크림 이름이 key 값 , 가격이 value 값이어야 합니다.
# * 돼지바 - 1000
# * 월드콘 - 1500
# * 죠스바 - 800

# %%
# 답안
icecream = {'돼지바':1000,'월드콘':1500,'죠스바':800};icecream
# Out:
# {'돼지바': 1000, '월드콘': 1500, '죠스바': 800}

# %% [markdown]
# #### (2) 딕셔너리에 다음의 품목들을 추가하세요.
# * 메로나 - 900
# * 누가바 - 1100

# %%
# 답안
icecream['메로나']=900
icecream['누가바']=1100
icecream
# Out:
# {'돼지바': 1300, '월드콘': 2000, '죠스바': 1300, '누가바': 1100, '메로나': 900}

# %% [markdown]
# #### (3) 위의 딕셔너리에서 월드콘의 가격을 2000원으로 수정하세요.

# %%
# 답안
icecream['월드콘']=2000
icecream
# Out:
# {'돼지바': 1300, '월드콘': 2000, '죠스바': 1300, '누가바': 1100, '메로나': 900}

# %% [markdown]
# #### (4) 위의 딕셔너리에서 메로나를 삭제하세요.

# %%
# 답안
del icecream['메로나']
icecream
# Out:
# {'돼지바': 1300, '월드콘': 2000, '죠스바': 1300, '누가바': 1100}

# %% [markdown]
# #### (5) 물가가 올라 모든 아이스크림의 가격이 200원씩 증가하였다고 할 때, `for` 구문을 이용하여 모든 가격을 수정하세요.

# %%
# 답안
ice = icecream.values()
cream=icecream.keys()
for c in cream:
    for i in ice:
        icecream[c]= i+ 200
        continue
icecream
# Out:
# {'돼지바': 1300, '월드콘': 1300, '죠스바': 1300, '누가바': 1700}

# %% [markdown]
# ### 9)  1 ~ x 까지의 숫자 합이 `1000 이상` 이 되는 가장 작은 정수 x를 출력하시오. (for문 사용)
#
# #### < OUTPUT >
#
# `1~x의 합이 1000 이상이 되는 가장 작은 정수 x = ?`

# %%
# 답안
num = [1:]
for n in num:
    if

# %% [markdown]
# ### 10)  용돈 11만원에서 매일 3000원씩 사용하되, 7일째 되는 날에는 그 두 배를 사용할 때, 남은 용돈이 있는 가장 늦은 날짜 수를 출력하세요. (while문 사용)
#
# `※ 7, 14, 21, ... 일째에 3000원의 두 배인 6000원을 사용하는 것입니다. ※`

# %%
# 답안
a = 110000
day=1
while a<=0:
    if d%%7 ==0:
        print(a-6000)
    else:
        print(a-3000)
        d= d+1
# Out:
#   File "<ipython-input-212-913176f4979f>", line 5
#     if d%%7 ==0:
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 11)  입력받은 수가 짝수인지 홀수인지 판별해주는 `eov` 라는 이름의 함수를 `def` 를 사용하여 만들고, 그 함수를 호출하여 1부터 100 사이의 `홀수`를 `리스트 형태`로 출력하시오.
#
# `→ 힌트 : append 함수 이용`

# %%
# 답안
ad = []
da = input()
def

# %% [markdown]
# ### 12)  주어진 정수가 소수인지 아닌지를 판단하는 `isprimenumber` 이라는 함수를 `def` 를 사용하여 만들고,  그 함수를 호출하여 2부터 100 사이의 소수를 리스트 형태로 출력하시오.
#
# ※ 소수 : 1과 자기 자신만으로 나누어 떨어지는 1보다 큰 양의 정수
#
# (1) def함수
# (2) for문
# 두 방법 각 방법으로 푸시오.

# %%
# 답안 (1)

# %%
# 답안 (2)

# %% [markdown]
# ### 13)  5개의 정수를 input을 통해 입력받고, 짝수는 짝수끼리 누적 합을 구하고, 홀수는 홀수끼리 누적 합을 구하는 프로그램을 작성하시오.
#
# 2, 5, 8, 12, 27 을 입력한 후 결과값을 출력하세요
#
# ` ※ 주의 : input 으로 입력받은 자료의 데이터타입이 무엇일지 생각해 보세요! `

# %%
# 답안

# %% [markdown]
# ### 14)  1부터 8까지 2x2x2의 3차원 array를 만들어주세요

# %%
import numpy as np
import pandas as pd

# %%
# 답안
d = np.array([[[1,2] , [3,4]] ,
             [[5,6],[7,8],]]) ; d
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %% [markdown]
# ### 15)  만든 array에서 '5'를 인덱싱해주세요

# %%
# 답안
d[1,0,0]
# Out:
# 5

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ------------- 이제부턴 Titanic 데이터를 활용하는 문제입니다 ----------------------------------
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 16) titanic 데이터를 불러서 출력해주세요.

# %%
# 답안
df=pd.read_csv('titanic.csv',sep=',')

# %% [markdown]
# ### 17)  titanic 데이터에서 살아남은 여성과 남성의 평균 나이를 구하세요 (1이 살아남은 것입니다)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# 답안
ddf=df.groupby(['Survived','Sex']).Age.mean()
ddf[1]
# Out:
# Sex
# female    28.847716
# male      27.276022
# Name: Age, dtype: float64

# %% [markdown]
# ### 18) PassengerId가 100번부터 400번 사이의 사람들의 Pclass별로 Fare의 평균을 구해주세요

# %%
# 답안
dff=df[100:401]
dff.groupby('Pclass').Fare.mean()
# Out:
# Pclass
# 1    95.571757
# 2    19.098652
# 3    13.599466
# Name: Fare, dtype: float64

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ------------- 이제부턴 dataTransactions 데이터를 활용하는 문제입니다 ----------------------------------
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 19) 숫자형 데이터가 담겨있는 열만 iloc을 이용해 뽑아주세요

# %%
df = pd.read_csv('dataTransactions.tab',sep='\t',encoding='cp949') ; df
# Out:
#                datetime  custid store        product     brand    corner  \
# 0      2000-05-01 10:43   18313   신촌점  4104840008000        샤넬       화장품
# 1      2000-05-01 11:00   18313   신촌점  2700000000000        식품      일반식품
# 2      2000-05-01 11:33   27222   신촌점  4545370944500      까사미아        가구
# 3      2000-05-01 11:43   27222   신촌점  4500860043900      대아통상        기타
# 4      2000-05-01 11:53   27222   신촌점  4538130048700     토이플러스      문화완구
# 5      2000-05-01 12:00   27222   신촌점  4406010020474        베베      유아동복
# 6      2000-05-01 12:00   47084   무역점  4421060026971     오마샤리프       스포츠
# 7      2000-05-01 12:03   27222   신촌점  4400280023100       NUK      유아동복
# 8      2000-05-01 12:03   31090   무역점  4408171025000    잭니클라우스       스포츠
# 9      2000-05-01 12:13   27222   신촌점  4401440022000      무냐무냐      유아동복
# 10     2000-05-01 12:23   27222   신촌점  2139141008000        랑콤       화장품
# 11     2000-05-01 12:30   27222   신촌점  2700000000000        식품      일반식품
# ...

# %%
# 답안
df.iloc[:,[0,1,3,6,7,8]]
# Out:
#                datetime  custid        product  import  amount  installment
# 0      2000-05-01 10:43   18313  4104840008000       1  113000            3
# 1      2000-05-01 11:00   18313  2700000000000       0   91950            3
# 2      2000-05-01 11:33   27222  4545370944500       0  598000            3
# 3      2000-05-01 11:43   27222  4500860043900       0   20100            1
# 4      2000-05-01 11:53   27222  4538130048700       0   24000            1
# 5      2000-05-01 12:00   27222  4406010020474       0   28000            1
# 6      2000-05-01 12:00   47084  4421060026971       0  150000            3
# 7      2000-05-01 12:03   27222  4400280023100       0   43800            1
# 8      2000-05-01 12:03   31090  4408171025000       0  118000            3
# 9      2000-05-01 12:13   27222  4401440022000       0   47000            1
# 10     2000-05-01 12:23   27222  2139141008000       0  143000            3
# ...

# %% [markdown]
# ### 20) 가장 비싼 제품을 구매한 고객의 아이디를 구하시오

# %%
# 답안
df.query('amount==amount.max()')
# Out:
#               datetime  custid store        product     brand corner  import  \
# 2149  2000-06-06 18:20   15968   천호점  4538790931071  SONY외수입품     기타       1
#
#        amount  installment
# 2149  8000000            1

# %% [markdown]
# ### 21) 금액이 100만원 이상인 데이터를 뽑은 후, corner 별로 각 몇개의 제품이 존재하는지 설명되어있는 데이터프레임을 출력하시오

# %%
# 답안
dfd = df.query('amount>=100')
dfd.groupby('corner').amount.count()
# Out:
# corner
# 가구            66
# 가전           244
# 기타           225
# 니트단품         730
# 도자기크리스탈      200
# 디자이너부띠끄      160
# 문화완구         548
# 생활용품           4
# 섬유           676
# 수입명품         353
# 스포츠         1129
# 엘레강스캐주얼      397
# 영캐주얼         853
# 유니캐주얼       1138
# 유아동복        1345
# 일반식품        5267
# 장신구          459
# 정장셔츠         317
# 조리욕실         431
# 침구수예         135
# 캐릭터캐주얼       766
# 타운모피          52
# 트래디셔널캐주얼     523
# 피혁           931
# 행사장           18
# 화장품         2158
# Name: amount, dtype: int64

# %% [markdown]
# ### 22) 수입품 중 가장 많이 수입되는 5개의 브랜드를 출력하세요

# %%
# 답안
ddfd = df.groupby('brand').amount.sum();ddfd
ddfd = pd.DataFrame({'bran':ddfd});ddfd
ddfd = ddfd.sort_values(['bran'],ascending=[False]).reset_index();ddfd
ddfd[0:5]
# Out:
#    brand       bran
# 0     식품  201662589
# 1    시슬리   24485700
# 2     랑콤   24217000
# 3    오브제   23265000
# 4  에스티로더   19443000

# %% [markdown]
# ### 23) 할부를 12개월을 한 고객들의 아이디를 뽑은 후, 12개월 할부의 빈도수가 가장 높은 고객의 데이터를 추출하세요.
#
# hint. 행은 총 92개입니다

# %%
# 답안
adf = df.query('installment==12')
bdf = adf.groupby('custid').count()
bdf.query('amount==amount.max()')
df.query('custid==27074')
# Out:
#                datetime  custid store        product   brand corner  import  \
# 1877   2000-06-03 16:10   27074    본점  4115920006000   세훈준보석    장신구       0
# 1880   2000-06-03 16:20   27074    본점  4104840008000      샤넬    화장품       1
# 1885   2000-06-03 16:50   27074    본점  4400213022200     압소바   유아동복       0
# 1889   2000-06-03 17:30   27074    본점  2700000000000      식품   일반식품       0
# 1890   2000-06-03 17:30   27074    본점  2700000000000      식품   일반식품       0
# 3273   2000-06-25 14:00   27074    본점  2800427813030  페레스튜디오   수입명품       1
# 3275   2000-06-25 14:10   27074    본점  2800427813000  페레스튜디오   수입명품       1
# 3276   2000-06-25 14:10   27074    본점  2800427813000  페레스튜디오   수입명품       1
# 3290   2000-06-25 15:40   27074    본점  4109161008000      겔랑    화장품       1
# 3294   2000-06-25 15:50   27074    본점  4109161008000      겔랑    화장품       1
# 3297   2000-06-25 16:00   27074    본점  4104840008000      샤넬    화장품       1
# ...

# %% [markdown]
# # 수고하셨습니다 :)
