# %% [markdown]
# # DAON 하계 파이썬 스터디 6회차 과제

# %% [markdown]
# #### 1. <파일 저장 형식> 'n회차_이름_과제'으로 저장하여 보내주세요!!(꼭 지켜주세요)
# #### 2. 못 풀고 끄적인 흔적이라도 남겨주셔도 괜찮아요! 나중에 꼭 다시 풀어주세요!!
# #### 3. 모든 결과를 출력해 주세요.

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
#수업시간 6번 문제

# %%
#고객별 연령대 ( 20대이하,20대,30대,40대,50대,60대 이상 )
cs = pd.read_table('dataCustomers.tab', sep='\t', encoding='cp949')
cs
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#      custid gender  age marriage      residence    job
# 0     10070      여   28       미혼     Yongsan-gu    제조업
# 1     10139      여   28       미혼    Gangdong-gu  정보서비스
# 2     10208      여   28       미혼    Gwangjin-gu    제조업
# 3     10275      여   28       미혼   Eunpyeong-gu   개인사업
# 4     10350      남   28       미혼     Gangnam-gu    제조업
# 5     10425      남   28       미혼      Songpa-gu   교육기관
# 6     10499      여   28       미혼   Seodaemun-gu   개인사업
# 7     10567      여   28       미혼     Dongjak-gu  정보서비스
# 8     10632      여   28       미혼   Eunpyeong-gu   개인사업
# 9     10707      여   28       기혼     Dongjak-gu   개인사업
# 10    10783      여   28       미혼     Dongjak-gu   개인사업
# 11    10853      여   28       미혼    Jungnang-gu    제조업
# 12    10919      여   28       기혼  Dongdaemun-gu   개인사업
# 13    10983      여   28       미혼     Gangnam-gu   의료기관
# ...

# %%
def f(x):
    if x<20:
        return '20대 이하'
    elif 20<= x <30:
        return '20대'
    elif 30<= x <40:
        return '30대'
    elif 40<= x <50:
        return '40대'
    elif 50<= x <60:
        return '50대'
    else:
        return '60대 이상'
cs['고객별 연령대'] = cs['age'].apply(f);cs
# Out:
#      custid gender  age marriage      residence    job 고객별 연령대
# 0     10070      여   28       미혼     Yongsan-gu    제조업     20대
# 1     10139      여   28       미혼    Gangdong-gu  정보서비스     20대
# 2     10208      여   28       미혼    Gwangjin-gu    제조업     20대
# 3     10275      여   28       미혼   Eunpyeong-gu   개인사업     20대
# 4     10350      남   28       미혼     Gangnam-gu    제조업     20대
# 5     10425      남   28       미혼      Songpa-gu   교육기관     20대
# 6     10499      여   28       미혼   Seodaemun-gu   개인사업     20대
# 7     10567      여   28       미혼     Dongjak-gu  정보서비스     20대
# 8     10632      여   28       미혼   Eunpyeong-gu   개인사업     20대
# 9     10707      여   28       기혼     Dongjak-gu   개인사업     20대
# 10    10783      여   28       미혼     Dongjak-gu   개인사업     20대
# 11    10853      여   28       미혼    Jungnang-gu    제조업     20대
# 12    10919      여   28       기혼  Dongdaemun-gu   개인사업     20대
# 13    10983      여   28       미혼     Gangnam-gu   의료기관     20대
# ...

# %%
cs = pd.read_table('dataCustomers.tab', sep='\t', encoding='cp949');cs
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#      custid gender  age marriage      residence    job
# 0     10070      여   28       미혼     Yongsan-gu    제조업
# 1     10139      여   28       미혼    Gangdong-gu  정보서비스
# 2     10208      여   28       미혼    Gwangjin-gu    제조업
# 3     10275      여   28       미혼   Eunpyeong-gu   개인사업
# 4     10350      남   28       미혼     Gangnam-gu    제조업
# 5     10425      남   28       미혼      Songpa-gu   교육기관
# 6     10499      여   28       미혼   Seodaemun-gu   개인사업
# 7     10567      여   28       미혼     Dongjak-gu  정보서비스
# 8     10632      여   28       미혼   Eunpyeong-gu   개인사업
# 9     10707      여   28       기혼     Dongjak-gu   개인사업
# 10    10783      여   28       미혼     Dongjak-gu   개인사업
# 11    10853      여   28       미혼    Jungnang-gu    제조업
# 12    10919      여   28       기혼  Dongdaemun-gu   개인사업
# ...

# %%
tr = pd.read_table('dataTransactions.tab', sep='\t', encoding='cp949');tr
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#                datetime  custid store        product     brand    corner  \
# 0      2000-05-01 10:43   18313   신촌점  4104840008000        샤넬       화장품
# 1      2000-05-01 11:00   18313   신촌점  2700000000000        식품      일반식품
# 2      2000-05-01 11:33   27222   신촌점  4545370944500      까사미아        가구
# 3      2000-05-01 11:43   27222   신촌점  4500860043900      대아통상        기타
# 4      2000-05-01 11:53   27222   신촌점  4538130048700     토이플러스      문화완구
# 5      2000-05-01 12:00   27222   신촌점  4406010020474        베베      유아동복
# 6      2000-05-01 12:00   47084   무역점  4421060026971     오마샤리프       스포츠
# 7      2000-05-01 12:03   27222   신촌점  4400280023100       NUK      유아동복
# 8      2000-05-01 12:03   31090   무역점  4408171025000    잭니클라우스       스포츠
# ...

# %% [markdown]
# **Exerxise1** 내점일수

# %%
tr.groupby('custid').datetime.count()
# Out:
# custid
# 10070     20
# 10139     16
# 10208    173
# 10275      7
# 10350     17
# 10425      3
# 10499     23
# 10567     18
# 10632     21
# 10707      7
# 10783      5
# 10853     11
# 10919      5
# 10983     29
# 11046     35
# 11113     36
# 11182     37
# 11264     68
# 11343      6
# 11421     61
# 11489     12
# 11563     11
# 11631      7
# 11694      2
# 11767     17
# 11843     56
# 11905     43
# 11969     10
# 12035      9
# 12105     23
#         ...
# 46230      1
# 46327     40
# 46441     18
# 46554    113
# 46661      8
# 46758      7
# 46869      6
# 46969     33
# 47084    163
# 47203     31
# 47319     10
# 47410      9
# 47523      7
# 47614     29
# 47739     59
# 47842     26
# 47956     36
# 48044     17
# 48169      6
# 48278    230
# 48401      4
# 48556     11
# 48686     19
# 48796      4
# 48890     46
# 48997    171
# 49112     12
# 49232     15
# 49351      9
# 49470     40
# Name: datetime, Length: 500, dtype: int64

# %% [markdown]
# **Exerxise2** 평균 할부개월수

# %%
tr.groupby('custid').installment.mean()
# Out:
# custid
# 10070    1.500000
# 10139    2.125000
# 10208    1.416185
# 10275    1.857143
# 10350    2.058824
# 10425    1.000000
# 10499    1.608696
# 10567    1.555556
# 10632    1.476190
# 10707    1.571429
# 10783    2.800000
# 10853    2.090909
# 10919    6.000000
# 10983    1.689655
# 11046    2.942857
# 11113    1.611111
# 11182    1.702703
# 11264    2.323529
# 11343    2.666667
# 11421    1.606557
# 11489    3.000000
# 11563    1.181818
# 11631    1.571429
# 11694    1.000000
# 11767    1.000000
# 11843    1.428571
# 11905    1.046512
# 11969    1.400000
# 12035    3.000000
# 12105    1.000000
#            ...
# 46230    1.000000
# 46327    2.250000
# 46441    2.444444
# 46554    1.477876
# 46661    1.750000
# 46758    2.142857
# 46869    2.000000
# 46969    2.848485
# 47084    1.208589
# 47203    2.064516
# 47319    2.300000
# 47410    2.222222
# 47523    1.714286
# 47614    2.206897
# 47739    1.033898
# 47842    1.769231
# 47956    2.222222
# 48044    1.823529
# ...

# %% [markdown]
# **Exerxise3**  'gap'의 'year' 칼럼을 1년씩 증가시켜 주세요.
#
# 작성한 코드 뒤에 보기 편하게 .head()를 붙여주시면 감사하겠습니다!!

# %%
gap = pd.read_csv('gapminder.tsv', sep = '\t');gap #꼭 실행시켜 주세요!
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
def f(x):
    return x+1
gap['year'] = gap['year'].apply(f)
gap
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1953   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1958   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1963   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1968   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1973   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1978   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1983   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1988   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1993   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1998   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2003   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2008   43.828  31889923   974.580338
# 12        Albania    Europe  1953   55.230   1282697  1601.056136
# ...

# %% [markdown]
# **Exerxise4** 'gap'의 'continent'가 'Aisa'일 경우 '1', 그 외의 나라일 경우 '2'로하여 새로운 열인 'Num'에 저장하세요.
#
# (Num 칼럼의 데이터타입은 object입니다.)

# %%
def f(x):
    if x == 'Asia':
        return '1'
    else:
        return '2'
gap['Num'] = gap['continent'].apply(f);gap
# Out:
#           country continent  year  lifeExp       pop    gdpPercap Num
# 0     Afghanistan      Asia  1953   28.801   8425333   779.445314   1
# 1     Afghanistan      Asia  1958   30.332   9240934   820.853030   1
# 2     Afghanistan      Asia  1963   31.997  10267083   853.100710   1
# 3     Afghanistan      Asia  1968   34.020  11537966   836.197138   1
# 4     Afghanistan      Asia  1973   36.088  13079460   739.981106   1
# 5     Afghanistan      Asia  1978   38.438  14880372   786.113360   1
# 6     Afghanistan      Asia  1983   39.854  12881816   978.011439   1
# 7     Afghanistan      Asia  1988   40.822  13867957   852.395945   1
# 8     Afghanistan      Asia  1993   41.674  16317921   649.341395   1
# 9     Afghanistan      Asia  1998   41.763  22227415   635.341351   1
# 10    Afghanistan      Asia  2003   42.129  25268405   726.734055   1
# 11    Afghanistan      Asia  2008   43.828  31889923   974.580338   1
# ...

# %% [markdown]
# **Exerxise5** 'weather' 데이터를 'weather' 변수에 할당하여 불러온 후, 'd2'와 'd27' 열의 결측값을 각각 1과 0으로 채워주세요.
#
# (단, 'weather'를 불러왔을 때, 'd2'와 'd27'이 1과 0으로 채워져 있어야 합니다.)

# %%
weather = pd.read_csv("weather.csv");weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
weathers = weather.fillna({'d2':1,'d7':0});weathers
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   1.0   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   1.0   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   1.0   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   1.0   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   1.0   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   1.0   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   1.0   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   1.0   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   1.0   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   1.0   NaN   NaN   NaN   NaN  ...
# ...

# %% [markdown]
# **Exerxise6**  'billboard' 데이터를 'bill' 변수에 할당하세요. 그 다음에 'time' 열에서 분만 추출하여 새로운 칼럼 'Min'에 저장하세요.
# (※ time열은 분:초)

# %%
bill = pd.read_csv('billboard.csv',sep = ',')
bill.head()
# Out:
#    year        artist                    track  time
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15
# 2  2000  3 Doors Down               Kryptonite  3:53
# 3  2000  3 Doors Down                    Loser  4:24
# 4  2000      504 Boyz            Wobble Wobble  3:35

# %%
def f(x):
    return x[0]
bill['Min'] = bill['time'].apply(f);bill
# Out:
#      year                artist                    track  time Min
# 0    2000                 2 Pac  Baby Don't Cry (Keep...  4:22   4
# 1    2000               2Ge+her  The Hardest Part Of ...  3:15   3
# 2    2000          3 Doors Down               Kryptonite  3:53   3
# 3    2000          3 Doors Down                    Loser  4:24   4
# 4    2000              504 Boyz            Wobble Wobble  3:35   3
# 5    2000                  98^0  Give Me Just One Nig...  3:24   3
# 6    2000               A*Teens            Dancing Queen  3:44   3
# 7    2000               Aaliyah            I Don't Wanna  4:15   4
# 8    2000               Aaliyah                Try Again  4:03   4
# 9    2000        Adams, Yolanda            Open My Heart  5:30   5
# 10   2000         Adkins, Trace                     More  3:05   3
# 11   2000   Aguilera, Christina  Come On Over Baby (A...  3:38   3
# 12   2000   Aguilera, Christina            I Turn To You  4:00   4
# ...
