# %% [markdown]
# # DAON 하계 파이썬 스터디 5회차 과제

# %% [markdown]
# #### 1. <파일 저장 형식> 'n회차_이름_과제'으로 저장하여 보내주세요!!(꼭 지켜주세요)
# #### 2. 못 풀고 끄적인 흔적이라도 남겨주셔도 괜찮아요! 나중에 꼭 다시 풀어주세요!!
# #### 3. 모든 결과를 출력해 주세요.

# %% [markdown]
# **Exercise 8**: Who produces more good rated movies, Steven Spielberg or James Cameron? Select the `director_name` column, but only  when said `director_name` is one of those two options, _and_ the `imdb_score` column is greater than or equal to 8.0.

# %%
#수업때 연습문제 숙제요!!!
movie2=movie.query('director_name in ["Steven Spielberg","James Cameron"] and imdb_score>=8.0')
movie2
movie3 = movie2.groupby('director_name').count();movie3
movie3['imdb_score'].idxmax()
# Out:
# 'Steven Spielberg'

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
# 데이터 불러오기
df = pd.read_csv('gapminder.tsv', sep='\t')
df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %% [markdown]
# # <1번>

# %% [markdown]
# (1) lifeExp 순으로(내림차순) 데이터를 정렬한 후 (※ 순서대로 정렬 구글링! hint.sort_~~)
# (2) lifeExp가 가장 높은 continent를 구하라

# %%
df.lifeExp.sort_values(ascending=False)
# Out:
# 803     82.603
# 671     82.208
# 802     82.000
# 695     81.757
# 1487    81.701
# 670     81.495
# 71      81.235
# 1427    80.941
# 1475    80.884
# 767     80.745
# 801     80.690
# 539     80.657
# 251     80.653
# 1486    80.620
# 779     80.546
# 694     80.500
# 70      80.370
# 778     80.240
# 1103    80.204
# 1151    80.196
# 1474    80.040
# 669     80.000
# 1367    79.972
# 83      79.829
# 1426    79.780
# 250     79.770
# 1091    79.762
# 766     79.696
# 538     79.590
# 599     79.483
#          ...
# 613     34.558
# 626     34.488
# 480     34.482
# 1347    34.113
# 504     34.078
# 3       34.020
# 38      34.000
# 1669    33.970
# 554     33.896
# 1033    33.779
# 948     33.685
# 612     33.609
# 625     33.489
# 1392    32.978
# 1346    32.767
# 1668    32.548
# 624     32.500
# 553     32.065
# 37      31.999
# 2       31.997
# 192     31.975
# 1345    31.570
# 1032    31.286
# 221     31.220
# 1       30.332
# 1344    30.331
# 36      30.015
# ...

# %%
dr = df.sort_values(['lifeExp','continent'],ascending=False);dr
dr = dr.reset_index(drop = True);dr
dr['continent'][0]
# Out:
# 'Asia'

# %% [markdown]
# # <2번>

# %% [markdown]
# Select the first row of data (the first record) from `gapminder`.
# (use three ways)

# %%
df.ix[0]
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %% [markdown]
# # <3번>

# %% [markdown]
#  Select the `continent` and `pop` columns of the first 101 records.

# %%
dff = df.iloc[0:102]
dff[['continent','pop']]
# Out:
#     continent       pop
# 0        Asia   8425333
# 1        Asia   9240934
# 2        Asia  10267083
# 3        Asia  11537966
# 4        Asia  13079460
# 5        Asia  14880372
# 6        Asia  12881816
# 7        Asia  13867957
# 8        Asia  16317921
# 9        Asia  22227415
# 10       Asia  25268405
# 11       Asia  31889923
# 12     Europe   1282697
# 13     Europe   1476505
# 14     Europe   1728137
# 15     Europe   1984060
# 16     Europe   2263554
# 17     Europe   2509048
# 18     Europe   2780097
# 19     Europe   3075321
# 20     Europe   3326498
# 21     Europe   3428038
# 22     Europe   3508512
# 23     Europe   3600523
# 24     Africa   9279525
# 25     Africa  10270856
# 26     Africa  11000948
# 27     Africa  12760499
# 28     Africa  14760787
# 29     Africa  17152804
# ..        ...       ...
# 72     Europe   6927772
# 73     Europe   6965860
# 74     Europe   7129864
# 75     Europe   7376998
# 76     Europe   7544201
# 77     Europe   7568430
# ...

# %% [markdown]
# # <4번>

# %% [markdown]
# Select the `gdpPercap` column for the last 1000 gdpPercap.

# %%
df.iloc[-1000:]['gdpPercap']
# Out:
# 704      1164.406809
# 705      1458.817442
# 706      1746.769454
# 707      2452.210407
# 708       749.681655
# 709       858.900271
# 710       849.289770
# 711       762.431772
# 712      1111.107907
# 713      1382.702056
# 714      1516.872988
# 715      1748.356961
# 716      2383.140898
# 717      3119.335603
# 718      2873.912870
# 719      3540.651564
# 720      3035.326002
# 721      3290.257643
# 722      4187.329802
# 723      5906.731805
# 724      9613.818607
# 725     11888.595080
# 726      7608.334602
# 727      6642.881371
# 728      7235.653188
# 729      8263.590301
# 730      9240.761975
# 731     11605.714490
# 732      4129.766056
# 733      6229.333562
#             ...
# 1674     1977.557010
# 1675     1971.741538
# 1676     1879.496673
# 1677     2117.484526
# 1678     2234.820827
# 1679     2280.769906
# 1680     1147.388831
# 1681     1311.956766
# 1682     1452.725766
# 1683     1777.077318
# 1684     1773.498265
# 1685     1588.688299
# ...

# %% [markdown]
# # <5번>

# %% [markdown]
# df의 continent마다의 lifeExp평균을 출력하시오 (소수점 2째자리에서 반올림하세요.)
# hint. 모르는건 구글링하세요 ^^

# %%
ddf = round(df.groupby('continent').mean(),2)
ddf['lifeExp']
# Out:
# continent
# Africa      48.87
# Americas    64.66
# Asia        60.06
# Europe      71.90
# Oceania     74.33
# Name: lifeExp, dtype: float64

# %% [markdown]
# # <6번>
# ```
# df에서 gdpPercap의 최댓값인 행을 query를 이용해 출력하시오
# ```

# %%
df.query('gdpPercap == gdpPercap.max()')
# Out:
#     country continent  year  lifeExp     pop    gdpPercap
# 853  Kuwait      Asia  1957   58.033  212846  113523.1329

# %% [markdown]
# # <7번>
# ```
# continent가 Asia 이면서 pop가 13000000 초과인 데이터를 추출해주세요
# ```

# %%
ddff = df.loc[(df['continent']=="Asia") & (df['pop']>13000000)];ddff
# Out:
#           country continent  year   lifeExp         pop     gdpPercap
# 4     Afghanistan      Asia  1972  36.08800    13079460    739.981106
# 5     Afghanistan      Asia  1977  38.43800    14880372    786.113360
# 7     Afghanistan      Asia  1987  40.82200    13867957    852.395945
# 8     Afghanistan      Asia  1992  41.67400    16317921    649.341395
# 9     Afghanistan      Asia  1997  41.76300    22227415    635.341351
# 10    Afghanistan      Asia  2002  42.12900    25268405    726.734055
# 11    Afghanistan      Asia  2007  43.82800    31889923    974.580338
# 96     Bangladesh      Asia  1952  37.48400    46886859    684.244172
# 97     Bangladesh      Asia  1957  39.34800    51365468    661.637458
# 98     Bangladesh      Asia  1962  41.21600    56839289    686.341554
# 99     Bangladesh      Asia  1967  43.45300    62821884    721.186086
# 100    Bangladesh      Asia  1972  45.25200    70759295    630.233627
# ...

# %% [markdown]
# # <8번>
# ```
# 위 7번 데이터에서 나라명의 고유한 값이 몇개인지 구해주세요
# ex. Korea , Vietnam , Vietnam 이라면 고유한 값은 Korea와 Vietnam 2개 입니다 !
# ```

# %%
ad  = ddff.groupby('country').count();ad
len(ad.index)
# Out:
# 23

# %% [markdown]
# # <9번>
# ```
# df에서 위에서 다섯개의 행과 country 열부터 year 열을 같이 추출하세요.
# (단, loc 과 iloc모두 이용해서 두 번 추출해주세요.)
# ```

# %%
df.loc[0:5,'country':'year']
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972
# 5  Afghanistan      Asia  1977

# %%
df.iloc[0:6,0:3]
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972
# 5  Afghanistan      Asia  1977

# %% [markdown]
# # <10번>
# ```
# year가 2000이상인 행의 lifeExp를 100으로 바꿔주세요.
# ```

# %%
bd = df.query('year>=2000')
bd['lifeExp']=100 ; bd
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                      country continent  year  lifeExp        pop     gdpPercap
# 10               Afghanistan      Asia  2002      100   25268405    726.734055
# 11               Afghanistan      Asia  2007      100   31889923    974.580338
# 22                   Albania    Europe  2002      100    3508512   4604.211737
# 23                   Albania    Europe  2007      100    3600523   5937.029526
# 34                   Algeria    Africa  2002      100   31287142   5288.040382
# 35                   Algeria    Africa  2007      100   33333216   6223.367465
# 46                    Angola    Africa  2002      100   10866106   2773.287312
# ...
